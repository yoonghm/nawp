# %%
# %%html
# <style>
# h1, h2, h3, h4, h5 {
#     color: darkblue;
#     font-weight: bold !important;
# }
# h2 {
#     border-bottom: 8px solid darkblue !important;
#     padding-bottom: 8px;
# }
# h3 {
#     border-bottom: 2px solid darkblue !important;
#     padding-bottom: 6px;
# }
# .info, .success, .warning, .error {
#     border: 1px solid;
#     margin: 10px 0px;
#     padding:15px 10px;
# }
# .info {
#     color: #00529b;
#     background-color: #bde5f8;
# }
# .success {
#     color: #4f8a10;
#     background-color: #dff2bf;
# }
# .warning {
#     color: #9f6000;
#     background-color: #FEEFB3;
# }
# .error {
#     color: #D8000C;
#     background-color: #FFBABA;
# }
# .language-bash {
#     font-weight: 900;
# }
# .ex {
#     font-weight: 900;
#     color: rgba(27,27,255,0.87) !important;
# }
# .mn {
#     font-family: Menlo, Consolas, "DejaVu Sans Mono", monospace
# }
# table {
#     margin-left: 0 !important;}
# </style>
# Out:
# <style>
# h1, h2, h3, h4, h5 {
#     color: darkblue;
#     font-weight: bold !important;
# }
# h2 {
#     border-bottom: 8px solid darkblue !important;
#     padding-bottom: 8px;
# }
# h3 {
#     border-bottom: 2px solid darkblue !important;
#     padding-bottom: 6px;
# }
# .info, .success, .warning, .error {
#     border: 1px solid;
#     margin: 10px 0px;
#     padding:15px 10px;
# }
# .info {
#     color: #00529b;
#     background-color: #bde5f8;
# }
# .success {
#     color: #4f8a10;
#     background-color: #dff2bf;
# }
# .warning {
#     color: #9f6000;
#     background-color: #FEEFB3;
# }
# .error {
#     color: #D8000C;
#     background-color: #FFBABA;
# }
# .language-bash {
#     font-weight: 900;
# }
# .ex {
#     font-weight: 900;
#     color: rgba(27,27,255,0.87) !important;
# }
# .mn {
#     font-family: Menlo, Consolas, "DejaVu Sans Mono", monospace
# }
# table {
#     margin-left: 0 !important;}
# </style>

# %% [markdown]
# # Day 2: Up and Running with Python

# %% [markdown]
# ## 2.7 Pandas

# %% [markdown]
# ### <span class='mn'>Pandas.read_csv()</span>

# %% [markdown]
# -   Pandas provides a rich set of functions to access data from a variety of sources, such as SQL, SQL databases, Excel, etc.
#
#
# -   `pandas.read_csv()` allows us to parse CSV files in different format into memory.
#
#
# -   Pandas provides `pandas.read_csv()` to parse a local copy of CSV file or from a given URL.
#
# Let's try to load the same CSV file from
# 1.  https://raw.githubusercontent.com/yoonghm/nawp/master/SalesJan2009.csv
# 2.  A local copy of `SalesJan2009.csv`

# %%
# !dir SalesJan2009.csv

# %% [markdown]
# #### Simple <span class='mn'>pandas.read_csv()</span>

# %%
import pandas as pd
import numpy as np

# Read the online URL as df1 in memory
df1 = pd.read_csv('https://raw.githubusercontent.com/yoonghm/nawp/master/SalesJan2009.csv')

# %%
df1.head()  # See the top five rows
# Out:
#   Transaction_date   Product  Price Payment_Type               Name  \
# 0      1/2/09 6:17  Product1   1200   Mastercard           carolina
# 1      1/2/09 4:53  Product1   1200         Visa             Betina
# 2     1/2/09 13:08  Product1   1200   Mastercard  Federica e Andrea
# 3     1/3/09 14:44  Product1   1200         Visa              Gouya
# 4     1/4/09 12:56  Product2   3600         Visa            Gerd W
#
#                            City     State         Country Account_Created  \
# 0                      Basildon   England  United Kingdom     1/2/09 6:00
# 1  Parkville                           MO   United States     1/2/09 4:42
# 2  Astoria                             OR   United States    1/1/09 16:21
# 3                        Echuca  Victoria       Australia   9/25/05 21:13
# 4  Cahaba Heights                      AL   United States  11/15/08 15:47
#
#      Last_Login   Latitude   Longitude
# 0   1/2/09 6:08  51.500000   -1.116667
# 1   1/2/09 7:49  39.195000  -94.681940
# 2  1/3/09 12:32  46.188060 -123.830000
# 3  1/3/09 14:22 -36.133333  144.750000
# 4  1/4/09 12:45  33.520560  -86.802500

# %%
df1.tail()  # See the bottom five rows
# Out:
#     Transaction_date   Product  Price Payment_Type        Name  \
# 993    1/22/09 14:25  Product1   1200         Visa  Hans-Joerg
# 994     1/28/09 5:36  Product2   3600         Visa  Christiane
# 995      1/1/09 4:24  Product3   7500         Amex      Pamela
# 996     1/8/09 11:55  Product1   1200       Diners       julie
# 997    1/12/09 21:30  Product1   1200         Visa      Julia
#
#                              City             State         Country  \
# 993                       Belfast  Northern Ireland  United Kingdom
# 994                   Black River       Black River       Mauritius
# 995  Skaneateles                                 NY   United States
# 996                     Haverhill           England  United Kingdom
# 997  Madison                                     WI   United States
#
#     Account_Created    Last_Login   Latitude  Longitude
# 993  11/10/08 12:15   3/1/09 3:37  54.583333  -5.933333
# 994     1/9/09 8:10   3/1/09 4:40 -20.360278  57.366111
# 995  12/28/08 17:28   3/1/09 7:21  42.946940 -76.429440
# 996  11/29/06 13:31   3/1/09 7:28  52.083333   0.433333
# 997  11/17/08 22:24  3/1/09 10:14  43.073060 -89.401110

# %% [markdown]
# #### Parse columns with the correct datatypes with <span class='mn'>pandas.read_csv()</span>

# %%
df1.info()  # See how Pandas parses the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 12 columns):
# Transaction_date    998 non-null object
# Product             998 non-null object
# Price               998 non-null object
# Payment_Type        998 non-null object
# Name                998 non-null object
# City                998 non-null object
# State               997 non-null object
# Country             998 non-null object
# Account_Created     998 non-null object
# Last_Login          998 non-null object
# Latitude            998 non-null float64
# Longitude           998 non-null float64
# dtypes: float64(2), object(10)
# memory usage: 93.7+ KB

# %% [markdown]
# It is noticed that the following columns were not parsed as datetime objects
# -   `Transaction_date` (0-index column),
# -   `Amount_Created` (8-index column),
# -   `Last_Login` (9-index column)
#
# and the following column was not parsed as integer objects
# -   `Price` (2-index column)
#
# There is a missing value for `State`.
#
# Let's use `parse_dates` parameters in `pandas.read_csv()` to parse datetime columns.

# %%
import pandas as pd
import numpy as np
from datetime import datetime

df1 = pd.read_csv(
    'https://raw.githubusercontent.com/yoonghm/nawp/master/SalesJan2009.csv',
    parse_dates=[0, 8, 9]
)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 12 columns):
# Transaction_date    998 non-null datetime64[ns]
# Product             998 non-null object
# Price               998 non-null object
# Payment_Type        998 non-null object
# Name                998 non-null object
# City                998 non-null object
# State               997 non-null object
# Country             998 non-null object
# Account_Created     998 non-null datetime64[ns]
# Last_Login          998 non-null datetime64[ns]
# Latitude            998 non-null float64
# Longitude           998 non-null float64
# dtypes: datetime64[ns](3), float64(2), object(7)
# memory usage: 93.7+ KB

# %% [markdown]
# Let's convert `Price` column to integer.

# %%
df1['Price'] = df1['Price'].astype(int)

# %% [markdown]
# Pandas could not convert `13,000`. Let's replace `,` with `` before convert the type again.

# %%
df1['Price'] = df1['Price'].str.replace(',', '').astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 12 columns):
# Transaction_date    998 non-null object
# Product             998 non-null object
# Price               998 non-null int32
# Payment_Type        998 non-null object
# Name                998 non-null object
# City                998 non-null object
# State               997 non-null object
# Country             998 non-null object
# Account_Created     998 non-null object
# Last_Login          998 non-null object
# Latitude            998 non-null float64
# Longitude           998 non-null float64
# dtypes: float64(2), int32(1), object(9)
# memory usage: 89.8+ KB

# %% [markdown]
# Find out more information on the missing value in `State` column.

# %%
df1[df1['State'].isnull()]  # List records from index with missing data in `State` column
# Out:
#     Transaction_date   Product Price Payment_Type      Name     City State  \
# 146     1/17/09 1:23  Product1  1200         Amex  Campbell  Mushrif   NaN
#
#     Country Account_Created    Last_Login   Latitude  Longitude
# 146  Kuwait   1/16/09 14:26  1/18/09 9:08  29.289167      48.05

# %% [markdown]
# ### Statistics from Numerical Columns

# %% [markdown]
# -   We could use `pandas.DataFrame.describe()` to find out statistics from numerical columns

# %%
df1.describe()
# Out:
#               Price    Latitude   Longitude
# count    998.000000  998.000000  998.000000
# mean    1633.767535   39.015705  -41.337820
# std     1156.034724   19.508572   67.389479
# min      250.000000  -41.465000 -159.485280
# 25%     1200.000000   35.816944  -87.991670
# 50%     1200.000000   42.320695  -73.730695
# 75%     1200.000000   51.050000    4.916667
# max    13000.000000   64.837780  174.766667

# %% [markdown]
# ### Display Rows using Index

# %%
df1[2:8]  # Show continous rows from id = 2 to id=7
# Out:
#   Transaction_date   Product  Price Payment_Type               Name  \
# 2     1/2/09 13:08  Product1   1200   Mastercard  Federica e Andrea
# 3     1/3/09 14:44  Product1   1200         Visa              Gouya
# 4     1/4/09 12:56  Product2   3600         Visa            Gerd W
# 5     1/4/09 13:19  Product1   1200         Visa           LAURENCE
# 6     1/4/09 20:11  Product1   1200   Mastercard              Fleur
# 7     1/2/09 20:09  Product1   1200   Mastercard               adam
#
#                            City     State        Country Account_Created  \
# 2  Astoria                             OR  United States    1/1/09 16:21
# 3                        Echuca  Victoria      Australia   9/25/05 21:13
# 4  Cahaba Heights                      AL  United States  11/15/08 15:47
# 5  Mickleton                           NJ  United States   9/24/08 15:19
# 6  Peoria                              IL  United States     1/3/09 9:38
# 7  Martin                              TN  United States    1/2/09 17:43
#
#      Last_Login   Latitude  Longitude
# 2  1/3/09 12:32  46.188060 -123.83000
# 3  1/3/09 14:22 -36.133333  144.75000
# 4  1/4/09 12:45  33.520560  -86.80250
# 5  1/4/09 13:04  39.790000  -75.23806
# 6  1/4/09 19:45  40.693610  -89.58889
# 7  1/4/09 20:01  36.343330  -88.85028

# %%
df1.loc[[2,4,6,8]]  # Show disjointed rows using DataFrame.loc
# Out:
#   Transaction_date   Product  Price Payment_Type               Name  \
# 2     1/2/09 13:08  Product1   1200   Mastercard  Federica e Andrea
# 4     1/4/09 12:56  Product2   3600         Visa            Gerd W
# 6     1/4/09 20:11  Product1   1200   Mastercard              Fleur
# 8     1/4/09 13:17  Product1   1200   Mastercard    Renee Elisabeth
#
#                            City     State        Country Account_Created  \
# 2  Astoria                             OR  United States    1/1/09 16:21
# 4  Cahaba Heights                      AL  United States  11/15/08 15:47
# 6  Peoria                              IL  United States     1/3/09 9:38
# 8                      Tel Aviv  Tel Aviv         Israel    1/4/09 13:03
#
#      Last_Login   Latitude   Longitude
# 2  1/3/09 12:32  46.188060 -123.830000
# 4  1/4/09 12:45  33.520560  -86.802500
# 6  1/4/09 19:45  40.693610  -89.588890
# 8  1/4/09 22:10  32.066667   34.766667

# %%
df1.loc[[1,3,5,7],['City','State','Country']]  # Show disjointed rows and particular columns
# Out:
#                            City     State        Country
# 1  Parkville                           MO  United States
# 3                        Echuca  Victoria      Australia
# 5  Mickleton                           NJ  United States
# 7  Martin                              TN  United States

# %%
df2[0:5]  # Show the last 5 rows from df2
# Out:
#   Transaction_date   Product Price Payment_Type               Name  \
# 0      1/2/09 6:17  Product1  1200   Mastercard           carolina
# 1      1/2/09 4:53  Product1  1200         Visa             Betina
# 2     1/2/09 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3     1/3/09 14:44  Product1  1200         Visa              Gouya
# 4     1/4/09 12:56  Product2  3600         Visa            Gerd W
#
#                            City     State         Country Account_Created  \
# 0                      Basildon   England  United Kingdom     1/2/09 6:00
# 1  Parkville                           MO   United States     1/2/09 4:42
# 2  Astoria                             OR   United States    1/1/09 16:21
# 3                        Echuca  Victoria       Australia   9/25/05 21:13
# 4  Cahaba Heights                      AL   United States  11/15/08 15:47
#
#      Last_Login   Latitude   Longitude
# 0   1/2/09 6:08  51.500000   -1.116667
# 1   1/2/09 7:49  39.195000  -94.681940
# 2  1/3/09 12:32  46.188060 -123.830000
# 3  1/3/09 14:22 -36.133333  144.750000
# 4  1/4/09 12:45  33.520560  -86.802500

# %% [markdown]
# ### Display Rows Sorted by Columns

# %%
# Return a new df with sorted rows by Payment_Type, 
# followed by Country in ascending orders
df1.sort_values(by=['Payment_Type', 'Country'])
# Out:
#     Transaction_date   Product  Price Payment_Type                  Name  \
# 606     1/25/09 5:57  Product1   1200         Amex                pamela
# 186      1/4/09 1:38  Product1   1200         Amex                jeremy
# 746     1/19/09 1:52  Product1   1200         Amex               Kirsten
# 123      1/7/09 7:19  Product1   1200         Amex               Jocelyn
# 780     1/19/09 6:50  Product1   1200         Amex                Nicola
# ..               ...       ...    ...          ...                   ...
# 963    1/22/09 12:45  Product3   7500         Visa  Frank and Christelle
# 967     1/14/09 8:38  Product1   1200         Visa               jingyan
# 970     1/3/09 21:19  Product1   1200         Visa         Doug and Tina
# 985    1/28/09 11:19  Product1   1200         Visa              christal
# 997    1/12/09 21:30  Product1   1200         Visa                Julia
#
#                              City                 State        Country  \
# 606                      Ayacucho          Buenos Aires      Argentina
# 186                   Charlestown       New South Wales      Australia
# 746                     Melbourne              Victoria      Australia
# 123                     Bruxelles  Brussels (Bruxelles)        Belgium
# 780                     Bruxelles  Brussels (Bruxelles)        Belgium
# ..                            ...                   ...            ...
# 963  Valley Center                                   CA  United States
# 967  Bristol                                         RI  United States
# 970  Pls Vrds Est                                    CA  United States
# 985  Morrison                                        CO  United States
# 997  Madison                                         WI  United States
#
#     Account_Created     Last_Login   Latitude   Longitude
# 606    1/24/09 9:29   2/10/09 6:38 -37.150000  -58.483333
# 186   7/15/08 21:04   1/20/09 1:08 -32.950000  151.666667
# 746    4/24/07 4:36   2/17/09 1:20 -37.816667  144.966667
# 123    6/30/08 9:33   1/16/09 8:54  50.833333    4.333333
# 780   7/13/08 11:29   2/18/09 2:30  50.833333    4.333333
# ..              ...            ...        ...         ...
# 963   1/22/09 10:25  2/27/09 10:49  33.218330 -117.033330
# 967   3/12/07 15:14  2/27/09 17:13  41.676940  -71.266670
# 970  12/24/07 22:59  2/27/09 21:40  33.800560 -118.389170
# 985   6/20/04 17:16  2/28/09 17:18  39.653610 -105.190560
# 997  11/17/08 22:24   3/1/09 10:14  43.073060  -89.401110
#
# [998 rows x 12 columns]

# %% [markdown]
# ### Display Rows Sorted by Columns in Different Orders

# %%
# Return a new df with sorted rows by Payment_Type in descending order,
# followed by Country in ascending order
df1.sort_values(by=['Payment_Type', 'Country'], ascending=[False, True])
# Out:
#     Transaction_date   Product  Price Payment_Type        Name  \
# 3       1/3/09 14:44  Product1   1200         Visa       Gouya
# 36      1/5/09 20:00  Product2   3600         Visa       James
# 55      1/11/09 2:04  Product1   1200         Visa       chris
# 120     1/12/09 1:37  Product1   1200         Visa        IMAN
# 199     1/20/09 3:51  Product1   1200         Visa   Elizabeth
# ..               ...       ...    ...          ...         ...
# 935     1/26/09 8:00  Product1   1200         Amex  Elizabeth
# 936     1/11/09 8:41  Product1   1200         Amex     Juliann
# 942     1/5/09 11:24  Product1   1200         Amex       Angie
# 951     1/13/09 7:09  Product2   3600         Amex        John
# 995      1/1/09 4:24  Product3   7500         Amex      Pamela
#
#                              City       State        Country Account_Created  \
# 3                          Echuca    Victoria      Australia   9/25/05 21:13
# 36                     Burpengary  Queensland      Australia  12/10/08 19:53
# 55                     Gold Coast  Queensland      Australia    1/11/09 0:33
# 120                      Brisbane  Queensland      Australia    1/12/09 1:26
# 199                    The Grange  Queensland      Australia   11/12/08 3:34
# ..                            ...         ...            ...             ...
# 935  Bluffton                              SC  United States   1/23/09 11:12
# 936  Winter Spgs                           FL  United States     1/8/08 7:24
# 942  Rodeo                                 CA  United States   1/25/08 16:50
# 951  Chicago                               IL  United States    1/8/09 13:49
# 995  Skaneateles                           NY  United States  12/28/08 17:28
#
#         Last_Login   Latitude   Longitude
# 3     1/3/09 14:22 -36.133333  144.750000
# 36    1/8/09 17:58 -27.166667  152.950000
# 55    1/11/09 2:11 -28.000000  153.433333
# 120  1/15/09 17:54 -27.500000  153.016667
# 199  1/20/09 13:11 -24.816667  152.416667
# ..             ...        ...         ...
# 935   2/26/09 7:49  32.236940  -80.860560
# 936   2/26/09 8:17  28.698610  -81.308330
# 942  2/26/09 12:15  38.017220 -122.287500
# 951  2/26/09 15:14  41.850000  -87.650000
# 995    3/1/09 7:21  42.946940  -76.429440
#
# [998 rows x 12 columns]

# %% [markdown]
# ### Display Top 5 Rows Sorted by Columns in Different Orders

# %%
# Return the first 5 rows after sorted by Payment_Type,
# followed by Country
df1.sort_values(by=['Payment_Type', 'Country'])[0:5]
# Out:
#     Transaction_date   Product  Price Payment_Type     Name         City  \
# 606     1/25/09 5:57  Product1   1200         Amex   pamela     Ayacucho
# 186      1/4/09 1:38  Product1   1200         Amex   jeremy  Charlestown
# 746     1/19/09 1:52  Product1   1200         Amex  Kirsten    Melbourne
# 123      1/7/09 7:19  Product1   1200         Amex  Jocelyn    Bruxelles
# 780     1/19/09 6:50  Product1   1200         Amex   Nicola    Bruxelles
#
#                     State    Country Account_Created    Last_Login   Latitude  \
# 606          Buenos Aires  Argentina    1/24/09 9:29  2/10/09 6:38 -37.150000
# 186       New South Wales  Australia   7/15/08 21:04  1/20/09 1:08 -32.950000
# 746              Victoria  Australia    4/24/07 4:36  2/17/09 1:20 -37.816667
# 123  Brussels (Bruxelles)    Belgium    6/30/08 9:33  1/16/09 8:54  50.833333
# 780  Brussels (Bruxelles)    Belgium   7/13/08 11:29  2/18/09 2:30  50.833333
#
#       Longitude
# 606  -58.483333
# 186  151.666667
# 746  144.966667
# 123    4.333333
# 780    4.333333

# %% [markdown]
# ### Display the Top 5 Highest Transactions with Payment Type

# %%
# Return the top 5 highest transaction with payment type
# followed by Country
df1.sort_values(by=['Price'], ascending=[False])[0:5][['Price','Payment_Type']]
# Out:
#      Price Payment_Type
# 558  13000         Visa
# 544   7500         Visa
# 963   7500         Visa
# 434   7500   Mastercard
# 493   7500         Visa

# %% [markdown]
# ### Display The Top 5 Highest Transaction in United States

# %%
# Return the top 5 highest transaction in United Kingdom
df1[df1.Country == 'United States'].sort_values(by=['Price'], ascending=False)[0:5]
# Out:
#     Transaction_date   Product  Price Payment_Type                  Name  \
# 558    1/28/09 18:00  Product1  13000         Visa               sandhya
# 206     1/16/09 2:41  Product3   7500         Visa               Kristyn
# 963    1/22/09 12:45  Product3   7500         Visa  Frank and Christelle
# 995      1/1/09 4:24  Product3   7500         Amex                Pamela
# 912    1/25/09 11:35  Product3   7500   Mastercard                 Anita
#
#                              City State        Country Account_Created  \
# 558  Centennial                      CO  United States   12/2/06 23:24
# 206  Kearns                          UT  United States   1/15/09 18:01
# 963  Valley Center                   CA  United States   1/22/09 10:25
# 995  Skaneateles                     NY  United States  12/28/08 17:28
# 912  Fresno                          TX  United States    1/24/09 9:24
#
#         Last_Login  Latitude  Longitude
# 558   2/7/09 15:18  39.57917 -104.87639
# 206   1/21/09 1:02  40.66000 -111.99556
# 963  2/27/09 10:49  33.21833 -117.03333
# 995    3/1/09 7:21  42.94694  -76.42944
# 912  2/25/09 14:22  29.53861  -95.44722

# %% [markdown]
# ### Loop Through The Top 5 Highest Transaction in United States

# %%
top5_df = df1[df1.Country == 'United States'].sort_values(by=['Price'], ascending=False)[0:5]
for d in top5_df.itertuples():
    print(f'{d.Name:<30} {d.City:<15} {d.Country:<20}')
# Out:
# sandhya                        Centennial                   United States
# Kristyn                        Kearns                       United States
# Frank and Christelle           Valley Center                United States
# Pamela                         Skaneateles                  United States
# Anita                          Fresno                       United States
